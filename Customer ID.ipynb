# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_excel(r"C:\Users\minu.mahajan\Downloads\OneDrive_2022-06-06\Data provided to Genpact\CUSTOMER LIST.xlsx")

# %%
df1
# Out:
#     Customer ID                    Customer Name  Customer Class  \
# 0         ACEHP          Ace Hotel  - Pittsburgh             800
# 1        ALBERT  Albertsons Store Support Center             102
# 2        AMAZON                       Amazon.com               1
# 3         ACELA                   Ace Hotel - LA             800
# 4         ACENO          Ace Hotel - New Orleans             800
# ..          ...                              ...             ...
# 343    SAMP OPS                 Samples Ops 5760             999
# 344  SAMP DAVID                SAMPLES - DAVID G             999
# 345     OLLIE'S           OLLIE'S BARGAIN OUTLET             500
# 346  IMPERIAL D                    IMPERIAL DIST             100
# 347     EMERSON           Emerson Ecologics, LLC             800
#
#          Description  Print Invoices               Type         Attention  \
# 0        Other Other            True           Customer  Accounts Payable
# ...

# %%
df2 = pd.read_excel(r"C:\Users\minu.mahajan\Downloads\OneDrive_2022-06-06\Data provided to Genpact\CUSTOMER LIST.xlsx",sheet_name = "CUSTOMER LOCATIONS")

# %%
df2
# Out:
#     Customer ID  LocationID                 Address Line 1  \
# 0        AMAZON       10998                 14601 Grant St
# 1        AMAZON       11176               5250 GOODMAN WAY
# 2        AMAZON       11002         10010 West Geiger Blvd
# 3        AMAZON       11000              4532 Newcastle Rd
# 4        AMAZON       11016              6855 Shannon Pkwy
# ..          ...         ...                            ...
# 133      COSTCO       10011              5100 Century Ave.
# 134      COSTCO       10013             3408 Bardstown Rd.
# 135    PETSMART       11366                 1200 VENICE DR
# 136        WALM        9173  Sams Distribution Center 6299
# 137        WALM        8914      WAL-MART DC 6016G-GENERAL
#
#              Address Line 2  Address Line 3           City State Country  \
# 0                      DEN3             NaN       Thornton    CO      US
# 1                       NaN             NaN       EASTVALE    CA      US
# ...

# %%
df1.columns = df1.columns.str.lower()

# %%
print(df1.info())
print(df1.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348 entries, 0 to 347
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer id               348 non-null    object
#  1   customer name             348 non-null    object
#  2   customer class            348 non-null    int64
#  3   description               348 non-null    object
#  4   print invoices            348 non-null    bool
#  5   type                      348 non-null    object
#  6   attention                 191 non-null    object
#  7   phone 1                   201 non-null    object
#  8   phone 2                   3 non-null      object
#  9   fax                       2 non-null      object
#  10  email                     294 non-null    object
#  11  address line 1            336 non-null    object
#  12  address line 2            53 non-null     object
# ...

# %%
df2.columns = df2.columns.str.lower()

# %%
print(df2.info())
print(df2.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer id     138 non-null    object
#  1   locationid      138 non-null    int64
#  2   address line 1  138 non-null    object
#  3   address line 2  6 non-null      object
#  4   address line 3  0 non-null      float64
#  5   city            138 non-null    object
#  6   state           138 non-null    object
#  7   country         138 non-null    object
#  8   postal code     138 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 9.8+ KB
# None
# (138, 9)

# %%
dfinal = df2.merge(df1, on="customer id", how = 'inner')

# %%
dfinal
# Out:
#     customer id  locationid               address line 1_x  \
# 0        AMAZON       10998                 14601 Grant St
# 1        AMAZON       11176               5250 GOODMAN WAY
# 2        AMAZON       11002         10010 West Geiger Blvd
# 3        AMAZON       11000              4532 Newcastle Rd
# 4        AMAZON       11016              6855 Shannon Pkwy
# ..          ...         ...                            ...
# 133      COSTCO       10011              5100 Century Ave.
# 134      COSTCO       10013             3408 Bardstown Rd.
# 135    PETSMART       11366                 1200 VENICE DR
# 136        WALM        9173  Sams Distribution Center 6299
# 137        WALM        8914      WAL-MART DC 6016G-GENERAL
#
#            address line 2_x  address line 3         city_x state_x country  \
# 0                      DEN3             NaN       Thornton      CO      US
# 1                       NaN             NaN       EASTVALE      CA      US
# ...
