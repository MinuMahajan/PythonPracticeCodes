# %%
import numpy as npH
import pandas as pd

# %%
df1 = pd.read_excel(r"C:\Users\minu.mahajan\Downloads\OneDrive_2022-06-06\Data provided to Genpact\FINANCE_COA.xlsx")

# %%
df1
# Out:
#      Account    Account Class  Adaptive Mapping       Type  Active  \
# 0       1000             CASH  SmartyPants Corp      Asset    True
# 1       1001             CASH  SmartyPants Corp      Asset   False
# 2       1002             CASH  SmartyPants Corp      Asset    True
# 3       1003             CASH  SmartyPants Corp      Asset    True
# 4       1004             CASH  SmartyPants Corp      Asset    True
# ..       ...              ...               ...        ...     ...
# 294     8200  NONOPEREXPENSES  SmartyPants Corp    Expense    True
# 295     9000              TAX  SmartyPants Corp    Expense    True
# 296     9010              TAX  SmartyPants Corp    Expense    True
# 297     9996           OPSLOG  SmartyPants Corp    Expense   False
# 298     9999               AP  SmartyPants Corp  Liability    True
#
#                         Description  Use Default Subaccount Post Option  \
# 0                        Petty Cash                   False      Detail
# ...

# %%
df2 = pd.read_excel(r"C:\Users\minu.mahajan\Downloads\OneDrive_2022-06-06\Data provided to Genpact\FINANCE_COA.xlsx",sheet_name = "Account Classes")

# %%
df2
# Out:
#    Account Class ID       Type               Description
# 0            ACCRUE  Liability          Accrued Expenses
# 1             ACCUM      Asset  Accumulated Depreciation
# 2                AP  Liability          Accounts Payable
# 3                AR      Asset       Accounts Receivable
# 4              CASH      Asset                      Cash
# ..              ...        ...                       ...
# 78  SLOTTNGFREEFILL     Income       Slotting, Free Fill
# 79              STD  Liability           Short Term Debt
# 80     SUBSCRIPTION  Liability   Subscription Receivable
# 81              TAX    Expense                       Tax
# 82             TRGL  Liability     Translation Gain/Loss
#
# [83 rows x 3 columns]

# %%
df1.columns = df1.columns.str.lower()

# %%
print(df1.info())
print(df1.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account                 299 non-null    int64
#  1   account class           299 non-null    object
#  2   adaptive mapping        298 non-null    object
#  3   type                    299 non-null    object
#  4   active                  299 non-null    bool
#  5   description             299 non-null    object
#  6   use default subaccount  299 non-null    bool
#  7   post option             299 non-null    object
#  8   consolidation account   0 non-null      float64
#  9   currency                11 non-null     object
#  10  cash account            299 non-null    bool
#  11  secured                 299 non-null    bool
#  12  revaluation rate type   0 non-null      float64
#  13  account group           0 non-null      float64
# ...

# %%
df2.columns = df2.columns.str.lower()

# %%
print(df2.info())
print(df2.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   account class id  83 non-null     object
#  1   type              83 non-null     object
#  2   description       83 non-null     object
# dtypes: object(3)
# memory usage: 2.1+ KB
# None
# (83, 3)

# %%
dfinal = df2.merge(df1, on="Account Class ID", how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 dfinal = df2.merge(df1, on="Account Class ID", how = 'inner')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
# ...

# %%
dfinal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 dfinal
#
# NameError: name 'dfinal' is not defined
